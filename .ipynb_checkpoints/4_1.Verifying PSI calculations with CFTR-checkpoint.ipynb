TEX-13JUV	GTEX-Y5V5	GTEX-14C38	GTEX-ZYVF	GTEX-14A5I	GTEX-ZVT2	GTEX-16NFA	GTEX-1GN1V	GTEX-145MH	GTEX-14BIM	GTEX-14PJN	GTEX-X4EP	GTEX-14PN3	GTEX-U3ZM	GTEX-QDVN	GTEX-ZEX8	GTEX-131YS	GTEX-14PQA	GTEX-15CHQ	GTEX-QVJO	GTEX-1314G	GTEX-R53T	GTEX-131XW	GTEX-1212Z	GTEX-14C39	GTEX-131XF	GTEX-111YS	GTEX-ZXES	GTEX-11WQK	GTEX-ZVP2	GTEX-Y8E4	GTEX-1GN2E	GTEX-14PJM'
samples = samples_in_genotype.split()

# %%
print("\t".join(samples))
# Out:
# GTEX-PLZ4	GTEX-NFK9	GTEX-OHPM	GTEX-X4EO	GTEX-UTHO	GTEX-TMZS	GTEX-WY7C	GTEX-P44H	GTEX-PWCY	GTEX-OIZF	GTEX-PSDG	GTEX-VJYA	GTEX-POMQ	GTEX-NL3H	GTEX-OXRN	GTEX-XOT4	GTEX-WK11	GTEX-S95S	GTEX-T6MO	GTEX-R55C	GTEX-RM2N	GTEX-SUCS	GTEX-XMK1	GTEX-XUW1	GTEX-WFG7	GTEX-OIZG	GTEX-R55G	GTEX-T6MN	GTEX-WCDI	GTEX-REY6	GTEX-OXRL	GTEX-OXRO	GTEX-S4P3	GTEX-OIZI	GTEX-N7MS	GTEX-O5YT	GTEX-TKQ2	GTEX-WHWD	GTEX-X3Y1	GTEX-Q2AH	GTEX-O5YW	GTEX-XPT6	GTEX-QXCU	GTEX-PWO3	GTEX-XGQ4	GTEX-RN64	GTEX-WFJO	GTEX-UPJH	GTEX-Q734	GTEX-PWOO	GTEX-X4XY	GTEX-RNOR	GTEX-XBED	GTEX-XXEK	GTEX-N7MT	GTEX-T5JC	GTEX-TSE9	GTEX-OXRP	GTEX-OHPN	GTEX-PWN1	GTEX-WVLH	GTEX-XQ3S	GTEX-S7SE	GTEX-WZTO	GTEX-VUSH	GTEX-SSA3	GTEX-UJHI	GTEX-OIZH	GTEX-S32W	GTEX-T8EM	GTEX-RWSA	GTEX-RWS6	GTEX-WFON	GTEX-P4QT	GTEX-PLZ5	GTEX-XOTO	GTEX-POYW	GTEX-P78B	GTEX-U3ZH	GTEX-RUSQ	GTEX-T2YK	GTEX-W5WG	GTEX-UPK5	GTEX-Q2AG	GTEX-PLZ6	GTEX-XV7Q	GTEX-WXYG	GTEX-T2IS	GTEX-R3RS	GTEX-X4XX	GTEX-TMMY	GTEX-W5X1	GTEX-P4QS	GTEX-UPIC	GTEX-WHSB	GTEX-QMRM	GTEX-X8HC	GTEX-U4B1	GTEX-QLQW	GTEX-NPJ
# ...

# %%
transcript_df = pd.read_table(FILE_ROOT + 'GTEx_Data_20150112_RNAseq_Flux1.6_transcript_reads.lung.txt',
                              dtype={"Gene_Symbol": str,'TargetID':str},
                              index_col=0,
                              sep='\t',
                              skipinitialspace=True)
# Out:
# /usr/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
lung_samples = transcript_df.columns[2:]

# %%
matched_samples = 0
not_matched_samples = 0

for sample in samples:
    found = False
    for lung_sample in lung_samples:
        if lung_sample.startswith(sample):
            matched_samples += 1
            found = True
            break
    if not found:
        not_matched_samples += 1

# %%
matched_samples
# Out:
# 307

# %%
not_matched_samples
# Out:
# 343

# %%
len(lung_samples)
# Out:
# 362

# %% [markdown]
# **Answer**: **YES 307/362** lung samples have the genotype present

# %% [markdown]
# ---
# # Percent Spliced In (PSI) calculations
# ---

# %% [markdown]
# ## Data necessary for PSI: exon reads and junction reads

# %% [markdown]
# ![title](https://github.com/mgymrek/mgymrek.github.io/blob/master/images/sqtl_psi.png?raw=true)

# %% [markdown]
# ### Exon reads: (A)

# %%
exon_df = pd.read_table(FILE_ROOT + 'GTEx_Data_20150112_RNAseq_RNASeQCv1.1.8_exon_reads.lung.txt',index_col=0)

# %%
exon_df
# Out:
#                       GTEX-1117F-0226-SM-5GZZ7  GTEX-1117F-0426-SM-5EGHI  \
# Id
# ENSG00000000003.10_0                   1106.46                    156.21
# ENSG00000000003.10_1                    163.18                     26.85
# ENSG00000000003.10_2                     97.53                     18.54
# ENSG00000000003.10_3                    167.22                     35.20
# ENSG00000000003.10_4                    121.17                     22.08
# ENSG00000000003.10_5                    100.76                     21.46
# ENSG00000000003.10_6                    176.34                     33.41
# ENSG00000000003.10_7                    206.33                     44.25
# ENSG00000000003.10_8                      0.00                      0.00
# ENSG00000000005.5_0                       8.92                      0.00
# ENSG00000000005.5_1                      10.80                      0.00
# ENSG00000000005.5_2                      64.82                      3.17
# ...

# %%
CFTR_exon_df = exon_df.loc[exon_df.index.str.startswith('ENSG00000001626')]
CFTR_exon_df['GTEX-ZF28-0726-SM-4WKFU']
# Out:
# Id
# ENSG00000001626.10_0      0.00
# ENSG00000001626.10_1      0.00
# ENSG00000001626.10_10     0.00
# ENSG00000001626.10_11     2.00
# ENSG00000001626.10_12     0.00
# ENSG00000001626.10_13     0.00
# ENSG00000001626.10_14     1.11
# ENSG00000001626.10_15     0.00
# ENSG00000001626.10_16     0.89
# ENSG00000001626.10_17     0.00
# ENSG00000001626.10_18     3.39
# ENSG00000001626.10_19     0.61
# ENSG00000001626.10_2      0.00
# ENSG00000001626.10_20     0.00
# ENSG00000001626.10_21     0.26
# ENSG00000001626.10_22     1.87
# ENSG00000001626.10_23     2.03
# ENSG00000001626.10_24     1.84
# ENSG00000001626.10_25     0.68
# ENSG00000001626.10_26     3.32
# ENSG00000001626.10_27     1.46
# ENSG00000001626.10_28     0.54
# ENSG00000001626.10_29     1.82
# ENSG00000001626.10_3      0.00
# ENSG00000001626.10_30     1.30
# ENSG00000001626.10_31    30.88
# ENSG00000001626.10_32     0.00
# ENSG00000001626.10_33     0.00
# ENSG00000001626.10_34     0.00
# ENSG00000001626.10_35    10.00
# ...

# %% [markdown]
# ## Removing samples with low total number of reads in the gene

# %%
CFTR_exon_sum = CFTR_exon_df.sum()
CFTR_exon_sum
# Out:
# GTEX-1117F-0226-SM-5GZZ7      72.00
# GTEX-1117F-0426-SM-5EGHI       2.00
# GTEX-1117F-0626-SM-5N9CS       2.00
# GTEX-14DAR-0226-SM-5S2PR    1657.01
# GTEX-139T6-0426-SM-5IJEM     824.02
# GTEX-111CU-0326-SM-5GZXO     808.00
# GTEX-YFC4-1126-SM-5RQJN       34.00
# GTEX-TML8-0326-SM-4GICN     2285.99
# GTEX-111FC-1126-SM-5GZWU      99.01
# GTEX-14E7W-1326-SM-5RQIV     483.99
# GTEX-YFCO-0426-SM-4W1Z7     1024.99
# GTEX-111VG-0726-SM-5GIDC     176.02
# GTEX-TMMY-0926-SM-33HBG     1771.81
# GTEX-TMMY-0926-SM-4TT1Z     1838.01
# GTEX-TMMY-0926-SM-4VBQZ     1189.00
# GTEX-TMMY-0926-SM-4WKH4      748.98
# GTEX-111YS-0626-SM-5GZXV    1306.01
# GTEX-139TT-0726-SM-5K7XW     140.99
# GTEX-N7MS-0926-SM-2HMIZ       41.00
# GTEX-1122O-0126-SM-5GICA     568.99
# GTEX-YJ8O-1826-SM-5HL82       55.99
# GTEX-TSE9-0726-SM-3DB8C       11.00
# GTEX-N7MT-0126-SM-2D7VT       18.00
# GTEX-139UW-0226-SM-5K7WU     227.98
# GTEX-1128S-0726-SM-5N9D6     157.98
# GTEX-139YR-0926-SM-5LZYB     866.02
# ...

# %%
plt.hist(CFTR_exon_sum,bins=100)
plt.show()

# %% [markdown]
# ### Removing the lowest 15th quantile : THIS MIGHT BE OVERKILL

# %%
CFTR_exon_trimmed = CFTR_exon_sum[CFTR_exon_sum > CFTR_exon_sum.quantile(q=0.15)]

# %%
plt.hist(CFTR_exon_trimmed,bins=100)
plt.show()

# %%
len(CFTR_exon_trimmed)
# Out:
# 309

# %%
CFTR_exon_trimmed_samples = CFTR_exon_trimmed.index

# %% [markdown]
# ### Junction reads: (B and C)

# %%
junction_df = pd.read_table(FILE_ROOT + 'GTEx_Data_20150112_RNAseq_Flux1.6_junction_reads.lung.txt',
                              index_col=0,
                              sep='\t',
                              skipinitialspace=True)
# Out:
# /usr/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
junction_df = junction_df[CFTR_exon_trimmed_samples]
junction_df
# Out:
#                         GTEX-1117F-0226-SM-5GZZ7  GTEX-14DAR-0226-SM-5S2PR  \
# TargetID
# 10_100008748_100010822                      38.0                      17.0
# 10_100010933_100011323                      32.0                       9.0
# 10_100011459_100012110                      36.0                      13.0
# 10_100011959_100015345                       0.0                       0.0
# 10_100012225_100013310                      41.0                      12.0
# 10_100013553_100015334                      21.0                      14.0
# 10_100015496_100016537                      27.0                      15.0
# 10_100016704_100017407                      20.0                      19.0
# 10_100017561_100017738                      15.0                       8.0
# 10_100017921_100018766                      20.0                       8.0
# 10_100018985_100019148                      19.0                       3.0
# ...

# %% [markdown]
# #### CFTR exon 10 id:

# %%
CFTR_e10 = 'ENSG00000001626.10_13'

# %%
A_reads = exon_df.loc[CFTR_e10]
A_reads = A_reads[CFTR_exon_trimmed_samples]

# %% [markdown]
# #### CFTR exon 10 junctions:

# %%
junction_ids = {'B_1':'7_117182162_117188695',
                'B_2':'7_117188877_117199518',
                'C':'7_117182162_117199518'}

# %%
B_reads = junction_df.loc[[junction_ids['B_1'],junction_ids['B_2']]]
B_reads = B_reads.iloc[:,2:].sum()

# %%
C_reads = junction_df.loc[[junction_ids['C']]]
C_reads = C_reads.iloc[:,2:].sum()

# %% [markdown]
# ### Calculation

# %%
A_B_reads = A_reads + B_reads

# %%
A_B_reads
# GTEX-111CU-0326-SM-5GZXO    100.000000
# GTEX-111FC-1126-SM-5GZWU    100.000000
# GTEX-111VG-0726-SM-5GIDC      0.000000
# GTEX-111YS-0626-SM-5GZXV     96.031746
# GTEX-1122O-0126-SM-5GICA    100.000000
# GTEX-1128S-0726-SM-5N9D6    100.000000
# GTEX-117YX-1326-SM-5H125    100.000000
# GTEX-11DXX-0626-SM-5Q5AG    100.000000
# GTEX-11DXZ-0726-SM-5N9C4    100.000000
# GTEX-11EMC-0126-SM-5EGKV    100.000000
# GTEX-11EQ9-0226-SM-5A5JX    100.000000
# GTEX-11GSP-0726-SM-5986L      0.000000
# GTEX-11I78-0126-SM-5HL6F    100.000000
# GTEX-11LCK-0426-SM-5A5M8    100.000000
# GTEX-11NSD-0326-SM-5A5LS    100.000000
# GTEX-11NUK-0826-SM-5HL4U     65.397924
# GTEX-11NV4-1126-SM-5HL6J    100.000000
# GTEX-11OF3-1126-SM-5986C    100.000000
# GTEX-11P7K-0326-SM-59871    100.000000
# GTEX-11P81-0226-SM-5HL5M    100.000000
# GTEX-11TT1-1626-SM-5EQL7    100.000000
# GTEX-11TUW-0526-SM-5LU9A      0.000000
# GTEX-11UD2-0726-SM-5EQ69    100.000000
# ...

# %% [markdown]
# ### Normalizing for JUST exon length

# %%
exon_len = math.fabs(117188695-117188877 + 1)
exon_len
# Out:
# 181.0

# %%
A_B_norm = (A_B_reads)/(exon_len-1)

# %%
C_norm = (C_reads)

# %%
PSI_norm = 100*((A_B_norm)/(A_B_norm + C_norm)) if (A_B_reads.sum() + C_reads.sum()) > 0.00 else 0
PSI_norm = PSI_norm.where(~mask,0)
PSI_norm
# Out:
# GTEX-1117F-0226-SM-5GZZ7           NaN
# GTEX-111CU-0326-SM-5GZXO    100.000000
# GTEX-111FC-1126-SM-5GZWU    100.000000
# GTEX-111VG-0726-SM-5GIDC      0.000000
# GTEX-111YS-0626-SM-5GZXV     11.851126
# GTEX-1122O-0126-SM-5GICA    100.000000
# GTEX-1128S-0726-SM-5N9D6    100.000000
# GTEX-117YX-1326-SM-5H125    100.000000
# GTEX-11DXX-0626-SM-5Q5AG    100.000000
# GTEX-11DXZ-0726-SM-5N9C4    100.000000
# GTEX-11EMC-0126-SM-5EGKV    100.000000
# GTEX-11EQ9-0226-SM-5A5JX    100.000000
# GTEX-11GSP-0726-SM-5986L      0.000000
# GTEX-11I78-0126-SM-5HL6F    100.000000
# GTEX-11LCK-0426-SM-5A5M8    100.000000
# GTEX-11NSD-0326-SM-5A5LS    100.000000
# GTEX-11NUK-0826-SM-5HL4U      1.039090
# GTEX-11NV4-1126-SM-5HL6J    100.000000
# GTEX-11OF3-1126-SM-5986C    100.000000
# GTEX-11P7K-0326-SM-59871    100.000000
# GTEX-11P81-0226-SM-5HL5M    100.000000
# GTEX-11TT1-1626-SM-5EQL7    100.000000
# GTEX-11TUW-0526-SM-5LU9A      0.000000
# GTEX-11UD2-0726-SM-5EQ69    100.000000
# ...

# %%
PSI_norm['GTEX-ZC5H-0926-SM-5CVMZ']
# Out:
# 2.8890507404709886

# %%
exon_df[exon_df.index.str.startswith('ENSG00000001626.10')]['GTEX-ZC5H-0926-SM-5CVMZ'].sum()
# Out:
# 836.0100000000001

# %%
import matplotlib.pylab as plt
# %matplotlib inline
plt.figure(figsize=(6,4))
plt.hist(PSI_norm.dropna(),bins=50)
plt.xlabel('Percent Spliced In (PSI)',fontsize=14)
plt.ylabel('Number of patients',fontsize=14)
plt.title('Histogram of PSI normalized by: \nexon length',fontsize=14,fontweight='bold')
plt.show()

# %% [markdown]
# ### It is super important to normalize by read length in addition to exon length, this lower distribution of samples are situations where reads are mostly inclusive reads.
# ![title](./images/PSI_norm_by_read_length.png)

# %% [markdown]
# ### Normalizing for exon length and read length

# %%
exon_len = math.fabs(117188695-117188877 + 1)
exon_len
# Out:
# 181.0

# %%
read_len = 75*2

# %%
A_B_norm = (A_B_reads)/(exon_len+read_len)

# %%
C_norm = (C_reads)/(read_len)

# %%
PSI_norm = 100*((A_B_norm)/(A_B_norm + C_norm)) if (A_B_reads.sum() + C_reads.sum()) > 0.00 else 0
PSI_norm = PSI_norm.where(~mask,0)

# %%
PSI_norm[(PSI_norm>0) & (PSI_norm<80)]
# Out:
# GTEX-11NUK-0826-SM-5HL4U    46.135069
# GTEX-12BJ1-1026-SM-5EGJA    69.619091
# GTEX-12WSA-1026-SM-5EGHN    74.059561
# GTEX-12WSE-0826-SM-5S2VL    31.185031
# GTEX-139T6-0426-SM-5IJEM    40.627803
# GTEX-13FTY-0126-SM-5J2NZ    18.472906
# GTEX-13RTJ-1126-SM-5S2UJ    52.408339
# GTEX-1497J-0326-SM-5Q5CN    62.641084
# GTEX-OHPL-0526-SM-4M1XS     72.946465
# GTEX-RWSA-1126-SM-2XCAZ     68.003867
# GTEX-SIU7-0526-SM-3NM8I     71.805792
# GTEX-SUCS-0626-SM-32PM5     24.729960
# GTEX-T8EM-0326-SM-3DB7F     79.893698
# GTEX-TMMY-0926-SM-4WKH4     74.120407
# GTEX-U3ZM-0426-SM-59HKR     61.195780
# GTEX-WH7G-0726-SM-5EQ6C     79.687021
# GTEX-X4LF-0526-SM-3NMB6     69.443803
# GTEX-XBEC-1026-SM-4QASM     60.571769
# GTEX-XGQ4-0826-SM-4AT4T     52.367247
# GTEX-ZC5H-0926-SM-5CVMZ     70.817721
# GTEX-ZQG8-0326-SM-51MSE     74.538462
# GTEX-ZUA1-1026-SM-4YCEA     77.544098
# GTEX-ZYT6-0526-SM-5GIEA     64.446831
# GTEX-ZYY3-0926-SM-5E454     60.000000
# dtype: float64

# %%
plt.figure(figsize=(6,4))
plt.hist(PSI_norm.dropna(),bins=50)
plt.xlabel('Percent Spliced In (PSI)',fontsize=14)
plt.ylabel('Number of patients',fontsize=14)
plt.title('Histogram of PSI normalized by: \nexon length and read count',fontsize=14,fontweight='bold')
plt.show()

# %%
PSI_norm_df = pd.DataFrame(PSI_norm, columns = ['ENSG00000001626.10_13'])
original_index = PSI_norm_df.index

# %% [markdown]
# ## These are duplicated samples, seeing quite different PSI values for these ones. It would be quite interesting to see how these samples differ and whether it may be possible that they have such different exon 10 epression.

# %%
abbr_index = ['-'.join(sample.split('-')[0:2]) for sample in list(original_index)]
PSI_norm_df.index = abbr_index
PSI_norm_df.loc[PSI_norm_df.index.duplicated()]
# Out:
#            ENSG00000001626.10_13
# GTEX-O5YV             100.000000
# GTEX-OHPL             100.000000
# GTEX-OHPL              72.946465
# GTEX-PLZ6             100.000000
# GTEX-PLZ6               0.000000
# GTEX-PVOW               0.000000
# GTEX-Q2AG             100.000000
# GTEX-QDVN              82.715405
# GTEX-QEG5              91.871316
# GTEX-QEG5              90.865186
# GTEX-QMRM             100.000000
# GTEX-TMMY             100.000000
# GTEX-TMMY              93.696439
# GTEX-TMMY              74.120407
# GTEX-U3ZM             100.000000
# GTEX-U3ZM              61.195780
# GTEX-WH7G             100.000000
# GTEX-WH7G              79.687021
# GTEX-WHSB             100.000000
# GTEX-WHSB             100.000000

# %%
PSI_norm_df = PSI_norm_df[~PSI_norm_df.index.duplicated(keep='first')]
PSI_norm_df = PSI_norm_df.dropna()

# %%
vals = np.array(PSI_norm_df)
m = np.mean(vals)
sd = math.sqrt(np.var(vals))
norm_vals = [(item-m)/sd for item in vals]
PSI_norm_df_z = pd.DataFrame(norm_vals,index= PSI_norm_df.index, columns = PSI_norm_df.columns)

# %%
PSI_norm_df_z
# Out:
#             ENSG00000001626.10_13
# GTEX-111CU               0.514939
# GTEX-111FC               0.514939
# GTEX-111VG              -2.543444
# GTEX-111YS               0.259366
# GTEX-1122O               0.514939
# GTEX-1128S               0.514939
# GTEX-117YX               0.514939
# GTEX-11DXX               0.514939
# GTEX-11DXZ               0.514939
# GTEX-11EMC               0.514939
# GTEX-11EQ9               0.514939
# GTEX-11GSP              -2.543444
# GTEX-11I78               0.514939
# GTEX-11LCK               0.514939
# GTEX-11NSD               0.514939
# GTEX-11NUK              -1.132457
# GTEX-11NV4               0.514939
# GTEX-11OF3               0.514939
# GTEX-11P7K               0.514939
# GTEX-11P81               0.514939
# GTEX-11TT1               0.514939
# GTEX-11TUW              -2.543444
# GTEX-11UD2               0.514939
# GTEX-11WQC              -2.543444
# GTEX-11WQK               0.514939
# GTEX-11ZTS              -2.543444
# ...

# %%
PSI_norm_df.to_csv('CFTR_PSI.csv')

# %% [markdown]
# ## PLOTTING CFTR exon 10

# %%
import argparse
import math
import numpy as np
import os
from collections import Counter
import pandas as pd
import random
import shutil
import statsmodels.api as sm
import statsmodels.formula.api as smf
import sys
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
STR = 117188661

# %%
expr = pd.read_csv('CFTR_PSI.csv',index_col=0)
strgt = pd.read_csv('Allele_Gentype_CFTR.table', sep="\t", low_memory=False)
expr_annot = pd.read_csv('/storage/dana/spliceSTR/expression/gencode.v19.annotations_exons.csv')
expr_annot.index = expr_annot["probe.id"].values
expr_annot = expr_annot.loc[[item for item in expr.columns if item in expr_annot.index],:]
gene = 'ENSG00000001626.10_13'

str_samples = list(set(strgt.columns[2:].values))
samples_to_remove = []
for item in str_samples:
    if item not in expr.index: samples_to_remove.append(item) #str_samples.remove(item)
for item in samples_to_remove: str_samples.remove(item)
expr = expr.loc[str_samples,:]
cis_strs = strgt[strgt['start'] == STR].dropna(axis=0)

for j in range(cis_strs.shape[0]):
    # cis STR data
    locus_str = cis_strs.iloc[[j],:][str_samples].transpose()
    locus_str.index = str_samples
    locus_str.columns = ["STR_%s"%(cis_strs["start"].values[j])]
    test_str=locus_str.columns[0]
    str_start = cis_strs["start"].values[j]
    
samples_to_keep = [str_samples[k] for k in range(len(str_samples)) if str(locus_str.iloc[:,0].values[k]) != "None" and  str(locus_str.iloc[:,0].values[k]) != 'NA,NA']

locus_str['x1'] = locus_str[test_str].apply(lambda x: x.split(',')[0] )
locus_str['x2'] = locus_str[test_str].apply(lambda x: x.split(',')[1] )
locus_str = locus_str.loc[samples_to_keep,:]

y = pd.DataFrame({"expr":list(expr.loc[:, gene])})
y.index = str_samples
locus_y = y.loc[samples_to_keep,:]
Locus_data = locus_str.join(locus_y)

# %%
#beta, beta_se, p = 
LinearRegression(locus_str, locus_y["expr"].values, norm=True, minsamples=0, alleles=True)
# Out:
# True True
# X:
# ...
# P-value:  0.5032571629427194

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
sns.set_style('darkgrid',{"axes.facecolor": "0.9",
                          'axes.grid' : True,
                          'grid.linestyle': u'-',
                          'xtick.major.size': 1,
                          'ytick.major.size': 0.5,})

sns.swarmplot(locus_str['x1+x2'].astype(int),locus_y["expr"],palette= sns.color_palette("Set2"),size=8)
plt.xlabel('STR length',fontsize=14,fontweight='bold')
plt.ylabel('PSI (%)',fontsize=14,fontweight='bold')
plt.title('CFTR exon 10 PSI vs. STR: {}'.format(STR),fontsize=25,fontweight='bold')
ax = plt.gca()
ax.grid(True)
plt.xticks(size = 20)
plt.yticks(size = 20)
plt.show()

# %%
sns.axes_style()
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': 'white',
#  'axes.facecolor': '0.9',
#  'axes.grid': True,
#  'axes.labelcolor': '.15',
#  'axes.linewidth': 0.0,
#  'figure.facecolor': 'white',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'image.cmap': 'Greys',
#  'legend.frameon': False,
#  'legend.numpoints': 1,
#  'legend.scatterpoints': 1,
#  'lines.solid_capstyle': 'round',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'xtick.direction': 'out',
#  'xtick.major.size': 1.0,
#  'xtick.minor.size': 0.0,
#  'ytick.color': '.15',
#  'ytick.direction': 'out',
#  'ytick.major.size': 0.5,
#  'ytick.minor.size': 0.0}

# %%
def ZNorm(vals,m,sd):
    if m is None:
        m = np.mean(vals)
        sd = math.sqrt(np.var(vals))
    if sd == 0: return None
    return [(item-m)/sd for item in vals]

def LinearRegression(data, Y, norm=False, minsamples=0, alleles=False):
    """
    Perform linear regression, return beta, beta_se, p
    """
    print(alleles, norm)
    if norm:
        if alleles:
            data['x1+x2'] = data['x1'].astype(float) + data['x2'].astype(float)
            X = ZNorm(data['x1+x2'], None, None)
        else:
            X = ZNorm(data,None, None) 
            Y = ZNorm(Y, None, None)
        if X is None or Y is None: return None, None, None
        if np.var(X)==0: return None, None, None
        if len(X) <= minsamples: return None, None, None
    else:
        X = data
        print('Here!!!!!!')
    X = sm.add_constant(X)
    print('X: '.format(X))
    mod_ols = sm.OLS(Y, X, missing='drop')
    print(mod_ols)
    res_ols = mod_ols.fit()
    pval = res_ols.pvalues[1]
    print('P-value: ', pval) 
    slope = res_ols.params[1]
    err = res_ols.bse[1]
    #return res_ols, slope, err, pval

# %%
import matplotlib.pylab as plt
expr = pd.read_table('CFTR_PSI.csv',sep=',',index_col = 0)
fav_str = strgt[strgt['start'] == 117188661]
fav_str = fav_str.transpose()
str_samples = list(set(strgt.columns[2:].values))
fav_str = fav_str.loc[str_samples]
fav_str_df = fav_str.loc[expr.index]
fav_str = fav_str[fav_str != 'NA,NA'].dropna()
fav_str['x1'] = fav_str[37].apply(lambda x: x.split(',')[0] )
fav_str['x2'] = fav_str[37].apply(lambda x: x.split(',')[1] )
fav_str['dosage'] = fav_str['x1'].astype(int) + fav_str['x2'].astype(int)
fav_str_df = fav_str['dosage']
fav_str_df = fav_str_df.sort_values()
plt.hist(fav_str_df)
plt.show()

# %%
expr.sort_values(by='ENSG00000001626.10_13')
# Out:
#             ENSG00000001626.10_13
# GTEX-14ABY                    0.0
# GTEX-11TUW                    0.0
# GTEX-11WQC                    0.0
# GTEX-11ZTS                    0.0
# GTEX-147JS                    0.0
# GTEX-X4EO                     0.0
# GTEX-X4XY                     0.0
# GTEX-13QJ3                    0.0
# GTEX-O5YV                     0.0
# GTEX-13OVJ                    0.0
# GTEX-12KS4                    0.0
# GTEX-13NZA                    0.0
# GTEX-13NYS                    0.0
# GTEX-13NYB                    0.0
# GTEX-13JVG                    0.0
# GTEX-13JUV                    0.0
# GTEX-Y111                     0.0
# GTEX-13O3P                    0.0
# GTEX-OXRN                     0.0
# GTEX-131XE                    0.0
# GTEX-VJYA                     0.0
# GTEX-RTLS                     0.0
# GTEX-111VG                    0.0
# GTEX-SE5C                     0.0
# GTEX-ZYVF                     0.0
# GTEX-T2IS                     0.0
# ...

# %%
fav_str.sort_values(by='dosage')
# Out:
#                37  x1  x2  dosage
# GTEX-11PRG  -7,-2  -7  -2      -9
# GTEX-13OVJ   0,-8   0  -8      -8
# GTEX-14C5O   0,-7   0  -7      -7
# GTEX-11P82   0,-7   0  -7      -7
# GTEX-11ZTS   0,-7   0  -7      -7
# GTEX-ZYT6    0,-7   0  -7      -7
# GTEX-16A39   0,-7   0  -7      -7
# GTEX-1B996   0,-7   0  -7      -7
# GTEX-1F75W   0,-7   0  -7      -7
# GTEX-13G51   0,-7   0  -7      -7
# GTEX-13PL6   0,-7   0  -7      -7
# GTEX-S3XE    0,-7   0  -7      -7
# GTEX-17HII   0,-7   0  -7      -7
# GTEX-15D79   0,-7   0  -7      -7
# GTEX-1A32A   0,-7   0  -7      -7
# GTEX-WY7C    0,-7   0  -7      -7
# GTEX-1GF9U   0,-7   0  -7      -7
# GTEX-RWSA    0,-7   0  -7      -7
# GTEX-QV31    0,-7   0  -7      -7
# GTEX-11XUK   0,-7   0  -7      -7
# GTEX-111FC   0,-7   0  -7      -7
# GTEX-11ZTT   0,-7   0  -7      -7
# GTEX-1AX9I   -7,2  -7   2      -5
# GTEX-16NFA  -2,-2  -2  -2      -4
# GTEX-13FLW  -2,-2  -2  -2      -4
# GTEX-WYBS   -2,-2  -2  -2      -4
# ...

# %%
short_length = fav_str[fav_str['dosage'] == -7]
for sample in short_length.index:
    try:
        print('PSI for {} is {}'.format(sample,expr.loc[sample]))
    except:
        print('not there')
# Out:
# PSI for GTEX-111FC is ENSG00000001626.10_13    100.0
# Name: GTEX-111FC, dtype: float64
# PSI for GTEX-11ZTT is ENSG00000001626.10_13    87.544685
# Name: GTEX-11ZTT, dtype: float64
# not there
# not there
# PSI for GTEX-11ZTS is ENSG00000001626.10_13    0.0
# Name: GTEX-11ZTS, dtype: float64
# PSI for GTEX-ZYT6 is ENSG00000001626.10_13    64.446831
# Name: GTEX-ZYT6, dtype: float64
# not there
# not there
# not there
# not there
# PSI for GTEX-13G51 is ENSG00000001626.10_13    100.0
# Name: GTEX-13G51, dtype: float64
# not there
# PSI for GTEX-RWSA is ENSG00000001626.10_13    68.003867
# Name: GTEX-RWSA, dtype: float64
# not there
# not there
# not there
# not there
# PSI for GTEX-WY7C is ENSG00000001626.10_13    100.0
# Name: GTEX-WY7C, dtype: float64
# not there
# not there
