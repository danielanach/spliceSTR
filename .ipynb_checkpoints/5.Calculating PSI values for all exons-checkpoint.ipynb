# %% [markdown]
# ## In this notebook, expanding upon the few examples performed and working on expanding PSI calculations across all exons

# %%
import pandas as pd
FILE_ROOT = '/storage/dana/spliceSTR/expression/'

# %%
exon_df = pd.read_table(FILE_ROOT + 'GTEx_Data_20150112_RNAseq_RNASeQCv1.1.8_exon_reads.lung.txt',index_col=0)

# %%
exon_annotations = pd.read_table(FILE_ROOT + 'gencode.v19.genes.patched_contigs_exons.txt',index_col=0)
# Out:
# /usr/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
exon_annotations
# Out:
#                      CHR     start      stop strand
# Gene
# ENSG00000223972.4_0    1     11869     12227      +
# ENSG00000223972.4_1    1     12595     12721      +
# ENSG00000223972.4_2    1     12975     13052      +
# ENSG00000227232.4_0    1     14970     15038      -
# ENSG00000227232.4_1    1     15796     15947      -
# ENSG00000227232.4_2    1     16607     16765      -
# ENSG00000227232.4_3    1     16854     17055      -
# ENSG00000227232.4_4    1     17233     17368      -
# ENSG00000227232.4_5    1     17498     17504      -
# ENSG00000227232.4_6    1     17602     17742      -
# ENSG00000227232.4_7    1     17915     18061      -
# ENSG00000227232.4_8    1     18268     18379      -
# ENSG00000227232.4_9    1     24734     24891      -
# ENSG00000227232.4_10   1     29321     29370      -
# ENSG00000227232.4_11   1     29534     29806      -
# ENSG00000243485.2_0    1     29554     30039      +
# ENSG00000243485.2_1    1     30267     30667      +
# ...

# %%
genes = [exon.split('_')[0] for exon in exon_df.index]
unique_genes = set(genes)

# %%
unique_genes
# Out:
# {'ENSG00000198963.6',
#  'ENSG00000221545.1',
#  'ENSG00000211879.1',
#  'ENSG00000227309.1',
#  'ENSG00000135114.8',
#  'ENSG00000258932.1',
#  'ENSG00000250954.1',
#  'ENSG00000250629.1',
#  'ENSG00000170743.12',
#  'ENSG00000141485.11',
#  'ENSG00000145839.1',
#  'ENSG00000238349.1',
#  'ENSG00000239005.1',
#  'ENSG00000166482.7',
#  'ENSG00000165188.9',
#  'ENSG00000270723.1',
#  'ENSG00000138650.7',
#  'ENSG00000165588.12',
#  'ENSG00000125571.5',
#  'ENSG00000224019.1',
#  'ENSG00000255778.1',
#  'ENSG00000156959.7',
#  'ENSG00000260102.1',
#  'ENSG00000207340.1',
#  'ENSG00000248429.1',
#  'ENSG00000143036.12',
#  'ENSG00000254641.1',
#  'ENSG00000225401.2',
#  'ENSG00000267150.1',
#  'ENSG00000271569.1',
#  'ENSG00000258784.1',
#  'ENSG00000266802.1',
#  'ENSG00000179029.10',
#  'ENSG00000253861.1',
#  'ENSG00000139344.3',
#  'ENSG00000259722.2',
#  'ENSG00000217372.2',
#  'ENSG00000264718.1',
#  'ENSG00000207946.1',
#  'ENSG00000234003.1',
#  'ENSG00000233983.2',
# ...

# %%
junction_df = pd.read_table(FILE_ROOT + 'GTEx_Data_20150112_RNAseq_Flux1.6_junction_reads.lung.txt',
                              index_col=0,
                              sep='\t',
                              skipinitialspace=True)
# Out:
# /usr/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
all_junctions = junction_df.index
all_junctions = [[junction.split('_')[0],int(junction.split('_')[1]),int(junction.split('_')[2])] for junction in all_junctions]

# %%
all_junctions
# Out:
# [['10', 100008748, 100010822],
#  ['10', 100010933, 100011323],
#  ['10', 100011459, 100012110],
#  ['10', 100011959, 100015345],
#  ['10', 100012225, 100013310],
#  ['10', 100013553, 100015334],
#  ['10', 100015496, 100016537],
#  ['10', 100016704, 100017407],
#  ['10', 100017561, 100017738],
#  ['10', 100017921, 100018766],
#  ['10', 100018985, 100019148],
#  ['10', 100019186, 100020679],
#  ['10', 100019186, 100021792],
#  ['10', 100019186, 100022500],
#  ['10', 100019186, 100027889],
#  ['10', 100020884, 100021792],
#  ['10', 100021970, 100022500],
#  ['10', 100022808, 100027889],
#  ['10', 100143625, 100144704],
#  ['10', 100144824, 100146958],
#  ['10', 100147064, 100147622],
#  ['10', 100147064, 100148111],
#  ['10', 100147064, 100150355],
#  ['10', 100147841, 100148111],
#  ['10', 100148265, 100150355],
#  ['10', 100150511, 100150628],
#  ['10', 100150511, 100150767],
#  ['10', 100150839, 100152189],
#  ['10', 100152323, 100152699],
#  ['10', 100152840, 100154953],
# ...

# %%
PSIs = pd.DataFrame(index=exon_df.index,columns=exon_df.columns)

# %%
for gene in unique_genes:
    
    
    exons = exon_df[exon_df.index.str.startswith(gene)].index
    for e in exons:
            
        e_info = exon_annotations.loc[e]
        c = exon_info['CHR']
        start =  int(exon_info['start'])
        stop =  int(exon_info['stop'])
        
        A = exon_df.loc[exon]
        
        junction_ids = {'B_1':None,
                        'B_2':None,
                        'C':None}
        
        break
    break

# %%
# Out:
# CHR              9
# start     77112281
# stop      77112899
# strand           +
# Name: ENSG00000198963.6_0, dtype: object

# %%
A
# Out:
# GTEX-1117F-0226-SM-5GZZ7     2.0
# GTEX-1117F-0426-SM-5EGHI     0.0
# GTEX-1117F-0626-SM-5N9CS     3.0
# GTEX-14DAR-0226-SM-5S2PR     0.0
# GTEX-139T6-0426-SM-5IJEM     2.0
# GTEX-111CU-0326-SM-5GZXO     0.0
# GTEX-YFC4-1126-SM-5RQJN      0.0
# GTEX-TML8-0326-SM-4GICN      6.0
# GTEX-111FC-1126-SM-5GZWU     4.0
# GTEX-14E7W-1326-SM-5RQIV     2.0
# GTEX-YFCO-0426-SM-4W1Z7      0.0
# GTEX-111VG-0726-SM-5GIDC    11.0
# GTEX-TMMY-0926-SM-33HBG     11.0
# GTEX-TMMY-0926-SM-4TT1Z     15.0
# GTEX-TMMY-0926-SM-4VBQZ     10.0
# GTEX-TMMY-0926-SM-4WKH4      3.0
# GTEX-111YS-0626-SM-5GZXV     4.0
# GTEX-139TT-0726-SM-5K7XW     6.0
# GTEX-N7MS-0926-SM-2HMIZ      4.0
# GTEX-1122O-0126-SM-5GICA     3.0
# GTEX-YJ8O-1826-SM-5HL82     15.0
# GTEX-TSE9-0726-SM-3DB8C      2.0
# GTEX-N7MT-0126-SM-2D7VT     10.0
# GTEX-139UW-0226-SM-5K7WU     2.0
# GTEX-1128S-0726-SM-5N9D6     2.0
# GTEX-139YR-0926-SM-5LZYB     4.0
# GTEX-U3ZH-0526-SM-3DB75      8.0
# GTEX-NFK9-1026-SM-2HMK1      4.0
# ...

# %%
e
